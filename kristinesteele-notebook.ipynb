# %% [markdown]
# # 📊 Data Light
#
# **Kristine Steele**
# *Intro to Jupyter Notebooks*
#
# ---
#
# Welcome to the Data Light analytics notebook!
# This notebook demonstrates how to use Jupyter for data exploration and visualization.
#
# - 🔗 [DataFun Project](https://github.com/ksteele3712/datafun_04_notebook)
# - 🔗 [Repository](https://github.com/ksteele3712/datafun_04_notebook)
#
# ---

# %% [markdown]
# ## Section 1. Getting Started
#
# This is a Markdown cell (not a Python cell).
# Here are a few tips to help you get started with Jupyter Notebooks:
#
# - To run a cell, press **Ctrl+Enter** (or **Cmd+Enter** on Mac) when you're done editing the cell.
# - You can change the type of a cell (e.g., code or markdown) by looking in the lower left corner of the notebook interface.
# - You can rearrange cells by dragging and dropping them within the notebook.
# - After creating a new notebook, use **File > Save as** to rename and save it into your repository folder.
# - To select a kernel (Python environment) for your notebook in Visual Studio Code, click on the **Select Kernel** name in the top-right corner of the notebook interface and choose the desired kernel from the dropdown menu. Follow suggestions to install recommended extensions. Once installed, click Select Kernel / Python Environments and choose the Recommended `.venv` option we created earlier. This will create a new kernel for the notebook and allow you to run code in the notebook using the packages installed in the virtual environment.

# %% [markdown]
# ## Section 2. Imports
#
# This is a Markdown cell.

# %%
# Imports still go at the top. This is a Python cell.

# Import from external packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import ipywidgets  # interactive widgets
import IPython  # used for display of widgets

# Type hint for Axes object (basic plot type returned by Seaborn)
# A seaborn plot is a set of axes and you can set the title, labels, etc. on the axes.
from matplotlib.axes import Axes

# A figure can contain multiple axes (plots)
# from matplotlib.figure import Figure

# %% [markdown]
# ## Section 3. Load and Explore Seaborn Penguins Dataset
#
# This is a Markdown cell.

# %%
# This cell is Python, so we can write Python code here.......

# Load the penguins dataset from Seaborn
# Into a pandas DataFrame (table)
penguins_df: pd.DataFrame = sns.load_dataset("penguins")

# Show a few lines from the start of the dataset
penguins_df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ## Section 4. Create a Seaborn Scatter Plot
#
# A scatter plot is used to visualize the relationship between two numerical variables.
# This is a Markdown cell.

# %%
# This cell is Python too - previous cells must be run first

# Create a scatter plot of penguin flipper length vs. body mass
# We need to know our dataset column names so we can use them to set x, y, and hue (color)
scatter_plt: Axes = sns.scatterplot(
    data=penguins_df, x="flipper_length_mm", y="body_mass_g", hue="species"
)

# Set axis labels using the Matplotlib Axes methods set_xlabel() and set_ylabel()
scatter_plt.set_xlabel("Flipper Length (mm)")
scatter_plt.set_ylabel("Body Mass (g)")

# Set the title using the Matplotlib Axes set_title() method
scatter_plt.set_title("Chart 1. Penguin Flipper Length vs. Body Mass (by Species)")

# Run this cell by clicking the play button (Execute cell and below) in the cell toolbar
# Or by pressing Shift+Enter
# Or by clicking Run ALL in the Menu above
# Out:
# Text(0.5, 1.0, 'Chart 1. Penguin Flipper Length vs. Body Mass (by Species)')

# %% [markdown]
# ## Section 5. Create a Seaborn Bar Plot
#
# A bar plot is used to show the relationship between a numerical variable and a categorical variable.
# This is a markdown cell.

# %%
# This is a Python cell
# Specify some sales data as a Python dictionary
sales_data_dict: dict = {"Category": ["A", "B", "C"], "Sales": [200, 150, 300]}

# Create a pandas DataFrame from the dictionary
sales_df: pd.DataFrame = pd.DataFrame(sales_data_dict)

# Create a Seaborn Bar Plot of Sales by Category
sales_plt: Axes = sns.barplot(x="Category", y="Sales", data=sales_df)

# Set the title using the Matplotlib Pyplot title() method
sales_plt.set_title("Chart 2. Sales by Category")
# Out:
# Text(0.5, 1.0, 'Chart 2. Sales by Category')

# %% [markdown]
# ## Section 6. Create an Interactive Widget with ipywidgets
#
# Add sliders, dropdowns, or interactive inputs to make the notebook dynamic.
# This is a Markdown cell.

# %%
# Section 6: Penguin Scatter Plot Example
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the penguins dataset
penguins_df = sns.load_dataset("penguins")

# Create a scatter plot of flipper length vs. body mass
scatter_plt = sns.scatterplot(
    data=penguins_df, x="flipper_length_mm", y="body_mass_g", hue="species"
)
scatter_plt.set_xlabel("Flipper Length (mm)")
scatter_plt.set_ylabel("Body Mass (g)")
scatter_plt.set_title("Chart 1. Penguin Flipper Length vs. Body Mass (by Species)")
plt.show()

# %% [markdown]
# ## Section 7. Reminder: Run All before sending to GitHub
#
# Before committing a notebook, use 'Run All' to generate all outputs and display them in the notebook.
# This is a Markdown cell.

# %% [markdown]
# ## Section 8. Example of Markdown Code with Headers, Titles, Text Style, Bullets, Numbered Lists, Links and More!
#
# This cell demonstrates various Markdown features you can use in Jupyter notebooks.

# %% [markdown]
# import sys
# print(sys.executable)
# # Main Title
#
# ## Section Title
#
# **Bold text**
# *Italic text*
# ~~Strikethrough~~
#
# - Bullet list item 1
# - Bullet list item 2
#
# 1. Numbered list item 1
# 2. Numbered list item 2
#
# [Link to Google](https://www.google.com)
#
# `Inline code`
#
# ```python
# # Code block example
# print("Hello, world!")

# %% [markdown]
# ## Section 9. Examples of Widgets, Sliders and Interactive Tools
#
# Below are interactive code examples you can run to explore widgets in Jupyter.

# %%
import ipywidgets as widgets
from IPython.display import display

slider = widgets.IntSlider(
    value=5,
    min=1,
    max=20,
    step=1,
    description='Value:',
    style={'description_width': 'initial'}
)
display(slider)
# Out:
# IntSlider(value=5, description='Value:', max=20, min=1, style=SliderStyle(description_width='initial'))

# %%
dropdown = widgets.Dropdown(
    options=['Penguin', 'Seal', 'Whale'],
    value='Penguin',
    description='Animal:',
    style={'description_width': 'initial'}
)
display(dropdown)
# Out:
# Dropdown(description='Animal:', options=('Penguin', 'Seal', 'Whale'), style=DescriptionStyle(description_width…

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_sine(freq):
    x = np.linspace(0, 2 * np.pi, 100)
    y = np.sin(freq * x)
    plt.plot(x, y)
    plt.title(f"Sine Wave (freq={freq})")
    plt.show()

widgets.interact(plot_sine, freq=widgets.IntSlider(min=1, max=10, step=1, value=1))
# Out:
# interactive(children=(IntSlider(value=1, description='freq', max=10, min=1), Output()), _dom_classes=('widget-…
# <function __main__.plot_sine(freq)>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example: Save a static image of a slider's effect (e.g., sine wave)
freq = 5  # Example slider value
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(freq * x)
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title(f"Sine Wave (freq={freq})")
fig.savefig("images/sine_wave_slider.png", bbox_inches="tight")
plt.close(fig)

# %% [markdown]
# ![Sine Wave Slider Output](images/sine_wave_slider.png)
#
# *Static image generated from the slider widget for GitHub viewers.*

# %% [markdown]
# ### Section 10. Advanced Widget Integration: Diamonds
#
# *some comment about a created graph

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the diamonds dataset
diamonds_df = sns.load_dataset("diamonds")

# Show basic statistics
print(diamonds_df.describe())

# Example plot: price vs carat, colored by cut
sns.scatterplot(data=diamonds_df, x="carat", y="price", hue="cut", alpha=0.5)
plt.title("Diamond Price vs Carat by Cut")
plt.show()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LogNorm, Normalize

# Interactive hexbin plot for diamonds dataset
def interactive_hexbin(gridsize=60, cmap='viridis', log_scale=True):
    plt.figure(figsize=(10,8))
    norm = LogNorm() if log_scale else Normalize()
    hb = plt.hexbin(diamonds_df['carat'], diamonds_df['price'], gridsize=gridsize, cmap=cmap, mincnt=1, norm=norm)
    plt.xlabel('Carat')
    plt.ylabel('Price')
    scale_text = 'Log Color Scale' if log_scale else 'Linear Color Scale'
    plt.title(f'Diamond Price vs Carat (Hexbin Plot, {scale_text})')
    cb = plt.colorbar(hb)
    cb.set_label(f'Count in bin ({"log" if log_scale else "linear"} scale)')
    plt.tight_layout()
    plt.show()

gridsize_slider = widgets.IntSlider(value=60, min=20, max=100, step=5, description='Grid Size')
cmap_dropdown = widgets.Dropdown(options=['viridis', 'plasma', 'Blues', 'inferno', 'magma'], value='viridis', description='Colormap')
logscale_toggle = widgets.Checkbox(value=True, description='Log Scale')

widgets.interact(interactive_hexbin, gridsize=gridsize_slider, cmap=cmap_dropdown, log_scale=logscale_toggle)
# Out:
# interactive(children=(IntSlider(value=60, description='Grid Size', min=20, step=5), Dropdown(description='Colo…
# <function __main__.interactive_hexbin(gridsize=60, cmap='viridis', log_scale=True)>

# %% [markdown]
# ### Section 10. Advanced Widget Integration: Diamonds
#
# *Interactively explore diamond prices by cut using the dropdown below.*
#
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import ipywidgets as widgets
#
# # Load the diamonds dataset
# diamonds_df = sns.load_dataset("diamonds")
#
# # Dropdown for cut selection
# cut_options = diamonds_df['cut'].dropna().unique().tolist()
# cut_dropdown = widgets.Dropdown(
#     options=cut_options,
#     value=cut_options[0],
#     description='Cut:',
#     style={'description_width': 'initial'}
# )
#
# def plot_diamonds_by_cut(selected_cut):
#     filtered = diamonds_df[diamonds_df['cut'] == selected_cut]
#     plt.figure(figsize=(7,5))
#     plt.scatter(filtered['carat'], filtered['price'], c='purple', alpha=0.5)
#     plt.xlabel('Carat')
#     plt.ylabel('Price')
#     plt.title(f'Diamond Price vs Carat for {selected_cut} Cut')
#     plt.grid(True)
#     plt.show()
#
# widgets.interact(plot_diamonds_by_cut, selected_cut=cut_dropdown)
